# %%
import pandas as pd
import matplotlib as plt
import numpy as np

from pydataset import data

# %%
## Exercise 1


np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']


math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# a.  add a column

df['passing_english'] = df.english >= 70

df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
# b. sort by catergory

df.sort_values('passing_english')
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
# c.  sorting by multiple categories

df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
#  d. more sorting

df.sort_values(by=['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
#  e. calculate total grade

df["overall_grade"] = round((df.math + df.english + df.reading)/3,0)

df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True           76.0
# 1      Jane    88       79       67             True           78.0
# 2     Suzie    94       74       95             True           88.0
# 3     Billy    98       96       88             True           94.0
# 4       Ada    77       92       98             True           89.0
# 5      John    79       76       93             True           83.0
# 6    Thomas    82       64       81            False           76.0
# 7     Marie    93       63       90            False           82.0
# 8    Albert    92       62       87            False           80.0
# 9   Richard    69       80       94             True           81.0
# 10    Isaac    92       99       93             True           95.0
# 11     Alan    92       62       72            False           75.0

# %%
## Exercise 2


mpg = data('mpg')

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
#  a. rows and columns?

mpg.shape
# Out:
# (234, 11)

# %%
#  b. data types for each column

mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
#  c. summarize with .info and . descirbe

mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#  d. rename cty to city

mpg.rename(columns={'cty':'city'})
mpg = mpg.rename(columns={'cty':'city'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
#  e. rename hwy to highway

mpg.rename(columns={'hwy':'highway'})
mpg = mpg.rename(columns={'hwy':'highway'})

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
#  f.  any cars peform better inb the city than on the highway?

[mpg.city > mpg.highway]
# Out:
# [1      False
#  2      False
#  3      False
#  4      False
#  5      False
#         ...
#  230    False
#  231    False
#  232    False
#  233    False
#  234    False
#  Length: 234, dtype: bool]

# %%
better_in_city = mpg[mpg.city > mpg.highway]

# %%
better_in_city
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %%
#  g. mileage difference (city vs. highway)

mpg['mileage_difference'] = mpg.highway - mpg.city

mpg.sort_values(by='mileage_difference')
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 107        honda  civic    1.8  2008    4  auto(l5)   f    24       36  c
#
#           class  mileage_difference
# 107  subcompact                  12

# %%
#  h.

mpg.sort_values(by='mileage_difference').tail(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 107        honda  civic    1.8  2008    4  auto(l5)   f    24       36  c
#
#           class  mileage_difference
# 107  subcompact                  12

# %%
#  i.  compact car with lowest/highest highway mileage?


#mpg_compact = (mpg[['class']] == 'compact')

#mpg_compact

#mpg[mpg_compact]


## ^^^^ not quite working how i'd like it to


[mpg['class'] == 'compact']


mpg_compact = mpg[mpg['class'] == 'compact']
mpg_compact.sample(5)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 214   volkswagen  jetta    2.0  1999    4  manual(m5)   f    21       29  r
# 210   volkswagen    gti    2.0  2008    4  manual(m6)   f    21       29  p
# 221   volkswagen  jetta    2.8  1999    6  manual(m5)   f    17       24  r
# 5           audi     a4    2.8  1999    6    auto(l5)   f    16       26  p
# 208   volkswagen    gti    2.0  1999    4  manual(m5)   f    21       29  r
#
#        class  mileage_difference  class_com
# 214  compact                   8       True
# 210  compact                   8       True
# 221  compact                   7       True
# 5    compact                  10       True
# 208  compact                   8       True

# %%
[mpg_compact.highway == mpg_compact.highway.min()]
# Out:
# [1      False
#  2      False
#  3      False
#  4      False
#  5      False
#  6      False
#  7      False
#  8      False
#  9      False
#  10     False
#  11     False
#  12     False
#  13     False
#  14     False
#  15     False
#  142    False
#  143    False
#  170    False
#  171    False
#  172    False
#  173    False
#  187    False
#  188    False
#  189    False
#  190    False
#  191    False
#  192    False
#  193    False
#  194    False
#  195    False
#  196    False
#  197    False
#  198    False
#  208    False
#  209    False
#  210    False
#  211    False
#  212    False
#  213    False
#  214    False
#  215    False
#  216    False
#  217    False
#  218    False
#  219    False
#  220     True
#  221    False
#  Name: highway, dtype: bool]

# %%
#lowest mileage


mpg_compact[mpg_compact.highway == mpg_compact.highway.min()]
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference  class_com
# 220  compact                   7       True

# %%
#highest mileage

mpg_compact[mpg_compact.highway == mpg_compact.highway.max()]
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference  class_com
# 213  compact                  11       True

# %%
#   j.  avg mileage of each car

mpg['average_mileage'] = (mpg.city + mpg.highway) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  class_com  average_mileage
# 1  compact                  11       True             23.5
# 2  compact                   8       True             25.0
# 3  compact                  11       True             25.5
# 4  compact                   9       True             25.5
# 5  compact                  10       True             21.0

# %%
#  k.  best/worst mileage for a dodge

mpg_dodge = mpg[mpg.manufacturer == 'dodge']

mpg_dodge.head(10)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
# 39        dodge  caravan 2wd    3.0  1999    6  auto(l4)   f    17       24
# 40        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16       22
# 41        dodge  caravan 2wd    3.3  1999    6  auto(l4)   f    16       22
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 44        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    11       17
# 45        dodge  caravan 2wd    3.8  1999    6  auto(l4)   f    15       22
# 46        dodge  caravan 2wd    3.8  1999    6  auto(l4)   f    15       21
# 47        dodge  caravan 2wd    3.8  2008    6  auto(l6)   f    16       23
#
#    fl    class  mileage_difference  class_com  average_mileage
# 38  r  minivan                   6      False             21.0
# ...

# %%
# similar to earlier question
# best first
mpg_dodge[mpg_dodge.average_mileage == mpg_dodge.average_mileage.max()]
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_difference  class_com  average_mileage
# 38  r  minivan                   6      False             21.0

# %%
# worst

mpg_dodge[mpg_dodge.average_mileage == mpg_dodge.average_mileage.min()]
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  class_com  average_mileage
# 55       12  e  pickup                   3      False             10.5
# 60       12  e     suv                   3      False             10.5
# 66       12  e  pickup                   3      False             10.5
# 70       12  e  pickup                   3      False             10.5

# %%
## Exercise 3

#  a.

from pydataset import data

mam = data('Mammals')

mam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
#   b.

mam.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
#   c.


mam.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
#    d. weight of fastest animal

mam.sort_values('speed').tail(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
#   e. overall percentage of specials

mam.specials.sum()
# Out:
# 10

# %%
len(mam)
# Out:
# 107

# %%
(mam.specials.sum() / len(mam)) * 100
# Out:
# 9.345794392523365

# %%
#    f.  what percentage are hoppers above median speed?

[(mam.hoppers == True) & (mam.speed > mam.speed.median())]
# Out:
# [1      False
#  2      False
#  3      False
#  4      False
#  5      False
#  6      False
#  7      False
#  8      False
#  9      False
#  10     False
#  11     False
#  12     False
#  13     False
#  14     False
#  15     False
#  16     False
#  17     False
#  18     False
#  19     False
#  20     False
#  21     False
#  22     False
#  23     False
#  24     False
#  25     False
#  26     False
#  27     False
#  28     False
#  29     False
#  30     False
#  31     False
#  32     False
#  33     False
#  34     False
#  35     False
#  36     False
#  37     False
#  38     False
#  39     False
#  40     False
#  41     False
#  42     False
#  43     False
#  44     False
#  45     False
#  46     False
#  47     False
#  48     False
#  49     False
#  50     False
#  51     False
#  52     False
#  53     False
#  54     False
#  55     False
#  56     False
#  57     False
#  58     False
#  59     False
#  60     False
#  61     False
#  62     False
# ...

# %%
mam[(mam.hoppers == True) & (mam.speed > mam.speed.median())]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
percentage = round(len(mam[(mam.hoppers == True) & (mam.speed > mam.speed.median())]) / len(mam),2)
(percentage) * 100
# Out:
# 7.000000000000001
